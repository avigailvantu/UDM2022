# %% [markdown]
# # Class 11: part 2
#
# NYU Tandon C4SUE @avigailvantu , April 2021
#
# ## Polygons, merging, more mapping features, and creating choropleth maps
#
# In this notebook we will be back to working with the NYT COVID-19 data that we worked with in the past few classes.

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
# %matplotlib inline 

import matplotlib.pyplot as plt
from shapely.geometry import Point
from geopandas import GeoDataFrame
from shapely.geometry import MultiPolygon
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %% [markdown]
# ## States boundries from the Census Buraeu
#
# Can be accessed here:
#
# https://www.census.gov/geographies/mapping-files/time-series/geo/carto-boundary-file.html

# %%
#load geodataframe
states = gpd.read_file('cb_2018_us_state_500k')

# %%
states.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS            NAME LSAD  \
# 0      28  01779790  0400000US28    28     MS     Mississippi   00
# 1      37  01027616  0400000US37    37     NC  North Carolina   00
# 2      40  01102857  0400000US40    40     OK        Oklahoma   00
# 3      51  01779803  0400000US51    51     VA        Virginia   00
# 4      54  01779805  0400000US54    54     WV   West Virginia   00
#
#           ALAND       AWATER  \
# 0  121533519481   3926919758
# 1  125923656064  13466071395
# 2  177662925723   3374587997
# 3  102257717110   8528531774
# 4   62266474513    489028543
#
#                                             geometry
# 0  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...
# 1  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...
# 2  POLYGON ((-103.00257 36.52659, -103.00219 36.6...
# 3  MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...
# 4  POLYGON ((-82.64320 38.16909, -82.64300 38.169...

# %%
states.plot( color='red',legend=True,figsize=(30, 12),markersize=0.1)
plt.axis('off')
plt.show()

# %%
states.plot( column='NAME',legend=False,figsize=(40, 10),markersize=0.1)
plt.axis('off')
plt.show()

# %% [markdown]
# ## COVID-19 data from the NYT
#
#
# https://github.com/nytimes/covid-19-data

# %%
#Load data

covidUS = pd.read_csv('us-states.csv')

# %%
covidUS.shape
# Out:
# (23059, 5)

# %%
#let's see the data  

covidUS.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %%
covidUS.tail()
# Out:
#              date          state  fips   cases  deaths
# 23054  2021-04-25       Virginia    51  654210   10691
# 23055  2021-04-25     Washington    53  397006    5478
# 23056  2021-04-25  West Virginia    54  151382    2821
# 23057  2021-04-25      Wisconsin    55  656668    7473
# 23058  2021-04-25        Wyoming    56   57696     705

# %% [markdown]
# # Create a DataFrame for April 18th, the last day in data

# %%
#filter as of the last day in the data

april2521 = covidUS[covidUS['date']== '2021-04-25']

# %%
#check out the new filtered data
april2521.shape
# Out:
# (55, 5)

# %% [markdown]
# # Time to merge data:
#
# We will merge data so that we are able to have the covid-19 data merged with the US countries boundries.
#
# The merge function works the same for DataFrame and GeoDataFrames. Basically, it joins two datasets based on a mutual attribute (column). Because our data is state based, we will merge based on that column. In geographical data, we will join the data without geogrpahical attirbutes (covid 19 for us), into the layer with the geomtery column (state shapfile).

# %%
#copy state column as a prep for merging datasets --> both need to be the same name
states['state'] = states['NAME']

# %%
# time to merge: 

states = states.merge(april2521, on='state')

# %%
#Check out merged data:

states.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS            NAME LSAD  \
# 0      28  01779790  0400000US28    28     MS     Mississippi   00
# 1      37  01027616  0400000US37    37     NC  North Carolina   00
# 2      40  01102857  0400000US40    40     OK        Oklahoma   00
# 3      51  01779803  0400000US51    51     VA        Virginia   00
# 4      54  01779805  0400000US54    54     WV   West Virginia   00
#
#           ALAND       AWATER  \
# 0  121533519481   3926919758
# 1  125923656064  13466071395
# 2  177662925723   3374587997
# 3  102257717110   8528531774
# 4   62266474513    489028543
#
#                                             geometry           state  \
# 0  MULTIPOLYGON (((-88.50297 30.21523, -88.49176 ...     Mississippi
# 1  MULTIPOLYGON (((-75.72681 35.93584, -75.71827 ...  North Carolina
# 2  POLYGON ((-103.00257 36.52659, -103.00219 36.6...        Oklahoma
# 3  MULTIPOLYGON (((-75.74241 37.80835, -75.74151 ...        Virginia
# 4  POLYGON ((-82.64320 38.16909, -82.64300 38.169...   West Virginia
#
#          date  fips   cases  deaths
# 0  2021-04-25    28  310349    7175
# 1  2021-04-25    37  963886   12553
# 2  2021-04-25    40  446550    6716
# 3  2021-04-25    51  654210   10691
# 4  2021-04-25    54  151382    2821

# %%
len(states)
# Out:
# 53

# %% [markdown]
# ## Visualize the merged data:

# %%
states.plot(column='cases',figsize=(30, 10),cmap='PuRd')

plt.title('cases')
plt.show()

# %% [markdown]
# ## Set a map x and y range
#
# Often the deafult of the map that will be plotted will not show the map in its ideal range. For example:

# %%
states.plot(column='cases',figsize=(60, 10),cmap='PuRd')

plt.title('cases by state')
plt.ylim((23,50))
plt.xlim((-130,-66))
plt.show()

# %% [markdown]
# ## And final touches-->
#
# - remove axis,
# - adjust title + its size & color
# - add legend

# %%
states.plot(column='cases',legend=True, figsize=(60, 10),cmap='PuRd')
plt.axis('off')
plt.title('COVID-19 cases by state as of April 18th', fontsize=23, color ='purple')
plt.ylim((23,50))
plt.xlim((-130,-66))
plt.show()

# %% [markdown]
# # Le'ts zoom into the the tri-state area
#
# To do so first let's plot the axis again so we can see the range of the coordinates we want to zoom into.

# %%
states.plot(column='cases',legend=True, figsize=(60, 10),cmap='PuRd')
#plt.axis('off')
plt.title('COVID-19 cases by state as of April 18th', fontsize=23, color ='purple')
#this is the y range
plt.ylim((23,50))
#this is the x range 
plt.xlim((-130,-66))
plt.show()

# %%
states.plot(column='cases',legend=True, figsize=(60, 10),cmap='PuRd')
#plt.axis('off')
plt.title('Tri-state area covid-19', fontsize=23, color ='purple')
plt.ylim((35,50))
plt.xlim((-80,-66))
plt.show()

# %% [markdown]
# # Now Let's Plot Multiple Plots Side-By-Side

# %%
#1.tri-state area 
ax1 = states.plot(column='cases',legend=True, figsize=(60, 10),cmap='summer') 
plt.title('Tri-state area covid-19', fontsize=23, color ='green')
plt.ylim((35,50))
plt.xlim((-80,-66))
plt.show()

#2. west coast 
ax2 = states.plot(column='cases', figsize=(60, 10),cmap='summer')
plt.title('West Coast COVID-19', fontsize=23, color ='green')
plt.ylim((28,50))
plt.xlim((-125,-110))
plt.show()

# %% [markdown]
# ## Finally, let's plot using quantiles

# %%
# install this package to use the "scheme" option

# %%
pip install mapclassify==2.4.0
# Out:
# Requirement already satisfied: mapclassify==2.4.0 in /opt/anaconda3/lib/python3.7/site-packages (2.4.0)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.7/site-packages (from mapclassify==2.4.0) (0.22.1)
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/lib/python3.7/site-packages (from mapclassify==2.4.0) (1.4.1)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.7/site-packages (from mapclassify==2.4.0) (2.6.3)
# Requirement already satisfied: pandas>=1.0 in /opt/anaconda3/lib/python3.7/site-packages (from mapclassify==2.4.0) (1.3.5)
# Requirement already satisfied: numpy>=1.3 in /opt/anaconda3/lib/python3.7/site-packages (from mapclassify==2.4.0) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.7/site-packages (from scikit-learn->mapclassify==2.4.0) (0.14.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.0->mapclassify==2.4.0) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=1.0->mapclassify==2.4.0) (2019.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->mapclassify==2.4.0) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
states.plot(column='cases',scheme='quantiles',k=5,figsize=(60, 10),cmap='PuRd')

plt.title('cases by state')
plt.ylim((23,50))
plt.xlim((-130,-66))
plt.show()

# %% [markdown]
# # Task 1:
#
# Can you plot 2 plots of the cases in the us:
# 1. For April 1st, 2020
# 2. For April 1st, 2021
#
# * What are some of the trends you found? Which trends have remained the same and which have changed in this past year?
#
# # Task 2:
#
# Can you visualize one state's cases only?
#
# # Task 3:
#
# using the below counties data, can you merge the data with NYS's counties and visualize the number of cases on April 25th 2021?
#
# If so, what were the steps that led you there? If not, what are some of the issues you faced and the techniques you looked into?
#
# Suggested places to look for counties shapefile:
# 1. https://catalog.data.gov/dataset/tiger-line-shapefile-2016-state-new-york-current-county-subdivision-state-based
# 2. https://cugir.library.cornell.edu/catalog/cugir-007865

# %%
counties = pd.read_csv('us-counties.csv')
counties[counties['state']=='New York']
# Out:
#                date         county     state     fips   cases  deaths
# 416      2020-03-01  New York City  New York      NaN       1     0.0
# 448      2020-03-02  New York City  New York      NaN       1     0.0
# 482      2020-03-03  New York City  New York      NaN       2     0.0
# 518      2020-03-04  New York City  New York      NaN       2     0.0
# 519      2020-03-04    Westchester  New York  36119.0       9     0.0
# ...             ...            ...       ...      ...     ...     ...
# 1256701  2021-04-25     Washington  New York  36115.0    2921    55.0
# 1256702  2021-04-25          Wayne  New York  36117.0    5377    67.0
# 1256703  2021-04-25    Westchester  New York  36119.0  127045  2249.0
# 1256704  2021-04-25        Wyoming  New York  36121.0    3336    51.0
# 1256705  2021-04-25          Yates  New York  36123.0    1125    26.0
#
# [23478 rows x 6 columns]

# %%
counties[counties['date']=='2021-03-01']
# Out:
#                date      county    state     fips  cases  deaths
# 1076224  2021-03-01     Autauga  Alabama   1001.0   6270    91.0
# 1076225  2021-03-01     Baldwin  Alabama   1003.0  19758   283.0
# 1076226  2021-03-01     Barbour  Alabama   1005.0   2116    51.0
# 1076227  2021-03-01        Bibb  Alabama   1007.0   2450    60.0
# 1076228  2021-03-01      Blount  Alabama   1009.0   6102   127.0
# ...             ...         ...      ...      ...    ...     ...
# 1079464  2021-03-01  Sweetwater  Wyoming  56037.0   3772    34.0
# 1079465  2021-03-01       Teton  Wyoming  56039.0   3357     9.0
# 1079466  2021-03-01       Uinta  Wyoming  56041.0   2055    12.0
# 1079467  2021-03-01    Washakie  Wyoming  56043.0    882    26.0
# 1079468  2021-03-01      Weston  Wyoming  56045.0    622     5.0
#
# [3245 rows x 6 columns]

# %%
#your code here...
